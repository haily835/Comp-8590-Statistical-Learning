# %% [markdown]
# Question 2.10

# %%
# %pip install ISLP
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ISLP-0.3.21-py3-none-any.whl (3.6 MB)
# ...
#      |████████████████████████████████| 840 kB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.0 MB 40.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 59.6 MB 21.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.9 MB 41.8 MB/s eta 0:00:01
# ...
#   Using cached pytorch_lightning-2.1.3-py3-none-any.whl (777 kB)
# ...
#      |████████████████████████████████| 4.5 MB 85.3 MB/s eta 0:00:01
# ...
#   Using cached pygam-0.9.0-py3-none-any.whl (522 kB)
# ...
#   Using cached progressbar2-4.3.2-py3-none-any.whl (50 kB)
# ...
#   Using cached python_utils-3.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# ...
#      |████████████████████████████████| 174 kB 26.0 MB/s eta 0:00:01
# ...
#   Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# ...

# %%
from ISLP import load_data
Boston = load_data('Boston')
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# b. How many rows are in this data set? How many columns? What do the rows and columns represent?
#
# Ref: https://islp.readthedocs.io/en/latest/datasets/Boston.html
#
# A data set containing housing values in 506 suburbs of Boston.
# - crim: per capita crime rate by town.
# - zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# - indus: proportion of non-retail business acres per town.
# - chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# - nox: nitrogen oxides concentration (parts per 10 million).
# - rm: average number of rooms per dwelling.
# - age: proportion of owner-occupied units built prior to 1940.
# - dis: weighted mean of distances to five Boston employment centres.
# - rad: index of accessibility to radial highways.
# - tax: full-value property-tax rate per $10,000.
# - ptratio: pupil-teacher ratio by town.
# - lstat: lower status of the population (percent).
# - medv: median value of owner-occupied homes in $1000s.

# %%
Boston.shape
# Out:
# (506, 13)

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# c. Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings

# %%
import pandas as pd
from matplotlib.pyplot import subplots


pd.plotting.scatter_matrix(Boston, figsize=(18, 18));

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
Boston.corr()['crim'].sort_values()
# Out:
# medv      -0.388305
# dis       -0.379670
# rm        -0.219247
# zn        -0.200469
# chas      -0.055892
# ptratio    0.289946
# age        0.352734
# indus      0.406583
# nox        0.420972
# lstat      0.455621
# tax        0.582764
# rad        0.625505
# crim       1.000000
# Name: crim, dtype: float64

# %%
Boston.plot.scatter('crim', 'rad');

# %%
Boston.plot.scatter('crim', 'tax');

# %%
Boston.plot.scatter('crim', 'lstat');

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
fig, axes = subplots(ncols=3, figsize=(15, 5))
Boston.hist('crim', color='red', ax=axes[0])
Boston.hist('tax', color='green', ax=axes[1])
Boston.hist('ptratio', color='blue', ax=axes[2]);

# %% [markdown]
# TODO Findings

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles river? => 35

# %%
Boston.loc[lambda df: df['chas'] == 1].shape
# Out:
# (35, 13)

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this data set? => 19.05

# %%
Boston['ptratio'].describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owneroccupied homes?
# What are the values of the other predictors for that suburb,
# and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
Boston.sort_values(by='medv')
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.35180   0.0  18.10     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666
# 400  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888   24  666
# 399   9.91655   0.0  18.10     0  0.693  5.852   77.8  1.5004   24  666
# 414  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 166   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459    5  403
# 195   0.01381  80.0   0.46     0  0.422  7.875   32.0  5.6484    4  255
# 283   0.01501  90.0   1.21     1  0.401  7.923   24.8  5.8850    1  198
# 225   0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 186   0.05602   0.0   2.46     0  0.488  7.831   53.6  3.1992    3  193
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0
# ...

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than seven rooms per dwelling?
# More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms per dwelling.

# %%
Boston.loc[lambda df: df['rm'] > 7].shape
# Out:
# (64, 13)

# %%
Boston.loc[lambda df: df['rm'] > 8].shape
# Out:
# (13, 13)
